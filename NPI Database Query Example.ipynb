# %%
import pandas as pd
from npi.npi import NPI
from npi.utils.utils import longprint

# %% [markdown]
# ### Instantiate an NPI object
#
# The NPI class provides convenient access to the NPI data housed in our shared folders.
#
# The canonical way to obtain an instance of this class is via (where entities=1 is specified if you only want to work with individuals)

# %%
npi = NPI(entities=1)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# * Function: get_entity
# * Metadata: {'func': 'get_entity', 'args': ['/work/akilby/npi/data/', None], 'kwargs': {}, 'code': {'get_entity': '-code snipped-'}}
# * (identified) Called functions: ['get_entity']
# * Cache found; loaded from ID 1587436437915440
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Display a list of data that can be currently managed by adding as an attibute

# %%
npi.display_gettable_attributes()
# Out:
# Gettable raw data:
#  ['PLICNUM', 'PLICSTATE', 'entity', 'npideactdate', 'npireactdate', 'pcredential', 'pcredentialoth', 'pfname', 'pfnameoth', 'plname', 'plnameoth', 'ploccityname', 'plocline1', 'plocline2', 'plocstatename', 'ploctel', 'ploczip', 'pmname', 'pmnameoth', 'pnamesuffix', 'pnamesuffixoth', 'ptaxcode']
#
#
# Gettable processed data:
#  ['credentials', 'expanded_fullnames', 'fullnames', 'licenses', 'practitioner_type', 'removaldate', 'secondary_practice_locations']

# %% [markdown]
# ### Retrieve all the data you need
#
# Hint: if you want to get rid of all the bulky output, run the below cell twice. The second time will be instantaneous and will clear the output.

# %%
npi.retrieve('removaldate')
npi.retrieve('fullnames')
npi.retrieve('practitioner_type')
npi.retrieve('plocstatename')
npi.retrieve('credentials')

# %% [markdown]
# ### Construct a dataset of NPI removals that can be used to search for people

# %% [markdown]
# 1. Get only doctors and advanced practice nurses for now

# %%
npi.practitioner_type.set_index('npi')[['MD/DO', 'CNM', 'CNS', 'CRNA', 'NP', 'Other APRN']]
# Out:
#             MD/DO  CNM  CNS  CRNA  NP  Other APRN
# npi
# 1003000100      0    0    0     0   0           0
# 1003000126      1    0    0     0   0           0
# 1003000134      1    0    0     0   0           0
# 1003000142      1    0    0     0   0           0
# 1003000159      0    0    0     0   1           0
# ...           ...  ...  ...   ...  ..         ...
# 1992999833      0    0    0     0   0           0
# 1992999858      0    0    0     0   0           0
# 1992999866      0    0    0     0   0           0
# 1992999874      1    0    0     0   0           0
# 1992999882      0    0    0     0   0           0
#
# [4910715 rows x 6 columns]

# %%
s = npi.practitioner_type.set_index('npi')[['MD/DO', 'CNM', 'CNS', 'CRNA', 'NP', 'Other APRN']].sum(axis=1) > 0 
mds_aprns = s[s].reset_index().drop(columns=0)

# %% [markdown]
# 2. Merge together the MD/APRN list with the deactivation list and their credentials

# %%
removed = npi.removaldate.merge(mds_aprns)
removed = removed.merge(npi.credentials)
removed = removed.drop(columns='pcredential_stripped')
removed
# Out:
#               npi npideactdate pcredential    cat
# 0      1003001660   2016-05-27          MD  MD/DO
# 1      1003003971   2019-11-04          MD  MD/DO
# 2      1003004326   2017-04-28          DO  MD/DO
# 3      1003006339   2014-04-30          MD  MD/DO
# 4      1003006479   2014-05-05          MD  MD/DO
# ...           ...          ...         ...    ...
# 50214  1992995732   2010-12-20          MD  MD/DO
# 50215  1992996169   2014-02-10          MD  MD/DO
# 50216  1992997316   2014-10-14          MD  MD/DO
# 50217  1992997761   2019-06-10          MD  MD/DO
# 50218  1992998306   2016-11-09          MD  MD/DO
#
# [50219 rows x 4 columns]

# %% [markdown]
# 3. Merge in the state locations in the month they are removed
#
# Here we are selecting the last month observed for each NPI, for convenience

# %%
states = npi.plocstatename.groupby('npi', as_index=False).last().drop(columns='month')

# %%
removed = removed.merge(states)

# %% [markdown]
# 4. Merge in full names

# %%
removed = removed.merge(npi.fullnames)

# %% [markdown]
# ### 60 most recent removals
#
# People can be duplicated if they have more than one value for fullname or credential. You can use this additional context to find people

# %%
removed.sort_values(['npideactdate', 'npi'])[-60:].head(60)
# Out:
#               npi npideactdate    pcredential      cat plocstatename  \
# 13297  1245387414   2020-04-24                     NaN            MD
# 29588  1548508435   2020-04-24             MD    MD/DO            PA
# 37111  1689984676   2020-04-24            FNP       NP            MD
# 37112  1689984676   2020-04-24            FNP       NP            MD
# 42141  1780662478   2020-04-24             DO    MD/DO            OH
# 49123  1912086810   2020-04-24             MD    MD/DO            FL
# 50329  1932212362   2020-04-24             MD    MD/DO            PA
# 52180  1962846956   2020-04-24             MD    MD/DO            NY
# 18740  1346545365   2020-04-27             MD    MD/DO            PA
# 21000  1386932986   2020-04-27             MD    MD/DO            OK
# 25579  1477640175   2020-04-27            DMD  Dentist            CA
# 33088  1619204609   2020-04-27        MD MACP      NaN            VA
# 42376  1780800722   2020-04-27             MD    MD/DO            GA
# 44838  1831167808   2020-04-27             MD    MD/DO            TN
# 45654  1841421476   2020-04-27             MD    MD/DO            CA
# 51143  1952306540   2020-04-27             MD    MD/DO            NY
# 253    1003854845   2020-04-28             MD    MD/DO            AL
# 5185   1093821910   2020-04-28             MD    MD/DO            CT
# 12955  1245216019   2020-04-28             MD    MD/DO            GA
# 22373  1417901281   2020-04-28             MD    MD/DO            IN
# 27667  1518236165   2020-04-28             MD    MD/DO            PA
# 31570  1588761159   2020-04-28             MD    MD/DO            NY
# 31901  1598751398   2020-04-28          FNP-C       NP            KY
# 31902  1598751398   2020-04-28  SISTER - APRN      NaN            KY
# 34003  1639130974   2020-04-28             DO    MD/DO            FL
# 34004  1639130974   2020-04-28             DO    MD/DO            FL
# 34005  1639130974   2020-04-28             DO    MD/DO            FL
# 3848   1073527628   2020-04-29             MD    MD/DO            WA
# 4729   1083817308   2020-04-29             MD    MD/DO            FL
# 11556  1215905005   2020-04-29             MD    MD/DO            TX
# 18760  1346598919   2020-04-29             MD    MD/DO            PA
# 22084  1407964612   2020-04-29             MD    MD/DO            IL
# 23141  1427418193   2020-04-29           ARNP       NP            FL
# 28144  1528061769   2020-04-29             MD    MD/DO            PA
# 31743  1598069692   2020-04-29             MD    MD/DO            NJ
# 31744  1598069692   2020-04-29             MD    MD/DO            NJ
# 36108  1679113690   2020-04-29            ESQ      NaN            NY
# 36109  1679113690   2020-04-29            ESQ      NaN            NY
# 36110  1679113690   2020-04-29            MPA      NaN            NY
# 36111  1679113690   2020-04-29            MPA      NaN            NY
# 36112  1679113690   2020-04-29             MD    MD/DO            NY
# 36113  1679113690   2020-04-29             MD    MD/DO            NY
# 53094  1982766283   2020-04-29             MD    MD/DO            NC
# 20850  1386768646   2020-04-30             MD    MD/DO            FL
# 27388  1508978669   2020-04-30             MD    MD/DO            WI
# 30123  1558639179   2020-04-30             MD    MD/DO            NY
# 39289  1730110321   2020-04-30             MD    MD/DO            TX
# 39552  1730216920   2020-04-30             MD    MD/DO            HI
# 69     1003131582   2020-05-01           ARNP       NP            KS
# 70     1003131582   2020-05-01           ARNP       NP            KS
# 5668   1104864511   2020-05-01             MD    MD/DO            ID
# 5669   1104864511   2020-05-01             MD    MD/DO            ID
# 5764   1104894559   2020-05-01             MD    MD/DO            NJ
# 6230   1114259306   2020-05-01             MD    MD/DO            IA
# 7411   1134201155   2020-05-01             MD    MD/DO            WA
# 8067   1144397597   2020-05-01             MD    MD/DO            CA
# 38538  1710954532   2020-05-01             MD    MD/DO            CA
# 38539  1710954532   2020-05-01             MD    MD/DO            CA
# 47613  1881708162   2020-05-01             MD    MD/DO            MD
# 47614  1881708162   2020-05-01             MD    MD/DO            MD
#
#            pfname       pmname           plname pnamesuffix  othflag
# 13297       JULIA            L          SURRATT                    0
# 29588      PARVIZ                        KAMBIN                    0
# 37111        RITA            M              LEE                    1
# 37112        RITA        MARIE       ROBERTAZZI                    0
# 42141        PAUL            R             WEST                    0
# 49123        MARK            I           TAFEEN                    0
# 50329     RUDOLPH           EM          JANOSKO                    0
# 52180     ANTHONY       EDWARD             LANG                    0
# 18740        JOHN      WILLIAM         REINHART                    0
# 21000      GEORGE         FRED        MCDONNOLD                    0
# 25579        JOHN            S             BOND                    0
# 33088   NATHANIEL       THOMAS         CONNALLY          JR        0
# 42376       SCOTT                     PATTERSON                    0
# 44838      JOSEPH            F          RALSTON          JR        0
# 45654     RUSSELL       ROBERT           REDLIN                    0
# 51143     ALFREDO        GUIAM             DAOS                    0
# 253        JOSEPH                     MICHALSKI                    0
# 5185      RICHARD                         KATES                    0
# 12955    MICHELLE            B           FUTRAL                    0
# 22373        JOHN            K        SCHNEIDER                    0
# 27667       HENRY       GEORGE        DEVINCENT                    0
# 31570     STEPHEN            L          FRIEDES                    0
# 31901        MARY         JOAN       GRIPSHOVER                    0
# 31902        MARY         JOAN       GRIPSHOVER                    0
# 34003       LINDA          LEA  MANNING-DIMMITT                    0
# 34004       LINDA          LEA           WILSON                    0
# 34005       LINDA  LEA MANNING           WILSON                    1
# 3848      SOLOMON                        KAMSON                    0
# 4729       ROBERT      LESLLIE       STEELE, SR                    0
# 11556         JON            R           GOGOLA                    0
# 18760     WILLIAM            H             LORD                    0
# 22084        JACK            L            GIBBS                    0
# 23141  ANNE MARIE                      THOMPSON                    0
# 28144      ARTHUR            J            KOVEL                    0
# 31743      TAJWAR                         AAMIR                    0
# 31744      TAJWAR      SULTANA            AAMIR                    1
# 36108     LINDSAY       ALEXIS             FIEL                    0
# 36109     LINDSAY       ALEXIS           VOIRIN                    1
# 36110     LINDSAY       ALEXIS             FIEL                    0
# 36111     LINDSAY       ALEXIS           VOIRIN                    1
# 36112     LINDSAY       ALEXIS             FIEL                    0
# 36113     LINDSAY       ALEXIS           VOIRIN                    1
# 53094      BALAJI                         PABBU                    0
# 20850    FERNANDO                        ORAMAS                    0
# 27388       JAMES         JOHN        SCERPELLA                    0
# 30123       JESUS       MANUEL         ZAMBRANO                    0
# 39289        TODD        MASON          MCCARTY                    0
# 39552     WALLACE          K C             CHUN                    0
# 69        KRISTEN            L        EDMONSTON                    0
# 70        KRISTEN            L          PROCTOR                    1
# 5668          JAY            S          KAUFMAN                    0
# 5669          JAY       STUART          KAUFMAN                    0
# 5764        BARRY          HAL         SAKOWITZ                    0
# 6230    ALEXANDER                      MATTHEWS                    0
# 7411       HAROLD         HUGH        MCCARTNEY                    0
# 8067         SAID            M            YUNES                    0
# 38538   O DOUGLAS                        WILSON                    0
# 38539  O. DOUGLAS                        WILSON                    0
# 47613    MOHAMMED            A           MANNAN                    0
# 47614    MOHAMMED        ABDUL           MANNAN                    0
